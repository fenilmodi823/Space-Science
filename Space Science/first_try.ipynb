# %%
import numpy as np 
print(np.random.randint(100))
# Out:
# 80

# %%
import matplotlib.pyplot as plt

plt.style.use("dark_background")

plt.figure(figsize=(10, 8))
plt.plot([1.0, 3.0], [2.0, 5.0])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')
